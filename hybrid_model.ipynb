# %% [markdown]
# <a href="https://colab.research.google.com/github/dah4ik/GenAI-Project/blob/main/hybrid_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. SETUP AND LIBRARIES
# ==========================================================
# !pip install -q ultralytics roboflow

import os
import cv2
import yaml
import shutil
from google.colab import drive
from ultralytics import YOLO
from roboflow import Roboflow

drive.mount('/content/drive')

# Paths based on your screenshots
BASE_DIR = '/content/drive/MyDrive/Shared drives/ChildSafetyProject'
SYNTHETIC_DIR = '/content/drive/MyDrive/Shared drives/genai_kids_room_project/synthetic_data'
RAW_IMAGES_DIR = os.path.join(BASE_DIR, 'raw_images')
FINAL_DATASET_DIR = os.path.join(BASE_DIR, 'final_combined_dataset')

# Create target directories
for split in ['train', 'val']:
    os.makedirs(os.path.join(FINAL_DATASET_DIR, split, 'images'), exist_ok=True)
    os.makedirs(os.path.join(FINAL_DATASET_DIR, split, 'labels'), exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 2. MODELS INITIALIZATION (For Auto-Annotation)
# ==========================================================
RF_API_KEY = "Qq253w1BrhEg30BxzESZ"
rf = Roboflow(api_key=RF_API_KEY)

def get_latest_model(workspace_id, project_id):
    """Automatically fetches the latest version of the specified Roboflow project"""
    project = rf.workspace(workspace_id).project(project_id)
    latest_v = project.versions()[0].version_number
    print(f"Loaded: {project_id} v{latest_v}")
    return project.version(latest_v).model

# Base YOLOv8 model for standard objects (Knives=43, Scissors=76, Bottles=39)
base_model = YOLO('yolov8s.pt')

# Custom models from Roboflow Universe
battery_model = rf.workspace("battery-detector").project("battery-x0y91").version(2).model
lego_model    = rf.workspace("concours-objets-intelligents").project("lego-aprqg").version(2).model
coin_model    = rf.workspace("rohith-xznmb").project("coins-lknzw").version(1).model
power_model   = rf.workspace("cjbs").project("cattle-upi-power").version(2).model
plastic_model = rf.workspace("snowman1908").project("plastic-recyclable-detection").version(1).model
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 200.2MB/s 0.1s
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# 3. MAPPING AND UTILS
# ==========================================================
MY_CLASSES = {
    'sharp_object': 0,
    'choking_hazard': 1,
    'electrical_hazard': 2,
    'chemical_danger': 3
}

def get_yolo_coords(pred, img_w, img_h):
    """Convert Roboflow dictionary prediction to YOLO string format"""
    xc = pred['x'] / img_w
    yc = pred['y'] / img_h
    nw = pred['width'] / img_w
    nh = pred['height'] / img_h
    return f"{xc:.6f} {yc:.6f} {nw:.6f} {nh:.6f}"

# %%
# 4. STAGE 1: AUTO-ANNOTATE SYNTHETIC DATA
# ==========================================================
print("STAGE 1: Annotating synthetic data with Fallback...")

for class_name, class_id in MY_CLASSES.items():
    synth_path = os.path.join(SYNTHETIC_DIR, class_name, 'images')
    if not os.path.exists(synth_path): continue

    files = [f for f in os.listdir(synth_path) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
    print(f"  Processing {class_name}...")

    for filename in files:
        img_path = os.path.join(synth_path, filename)
        image = cv2.imread(img_path)
        if image is None: continue
        h, w, _ = image.shape
        labels = []

        # AI Detection attempt
        if class_name == 'sharp_object':
            res = base_model(image)[0]
            for box in res.boxes:
                if int(box.cls) in [43, 76]:
                    xywh = box.xywhn[0].tolist()
                    labels.append(f"{class_id} {xywh[0]:.6f} {xywh[1]:.6f} {xywh[2]:.6f} {xywh[3]:.6f}")

        elif class_name == 'choking_hazard':
            for m in [battery_model, lego_model, coin_model]:
                preds = m.predict(img_path, confidence=30).json()['predictions']
                for p in preds: labels.append(f"{class_id} {get_yolo_coords(p, w, h)}")

        elif class_name == 'electrical_hazard':
            preds = power_model.predict(img_path, confidence=30).json()['predictions']
            for p in preds: labels.append(f"{class_id} {get_yolo_coords(p, w, h)}")

        elif class_name == 'chemical_danger':
            res = base_model(image)[0]
            for box in res.boxes:
                if int(box.cls) == 39:
                    xywh = box.xywhn[0].tolist()
                    labels.append(f"{class_id} {xywh[0]:.6f} {xywh[1]:.6f} {xywh[2]:.6f} {xywh[3]:.6f}")

        # --- FALLBACK: If AI found nothing in a dedicated folder, mark center ---
        if not labels:
            # 0.5 0.5 is center, 0.8 0.8 is 80% width/height
            labels.append(f"{class_id} 0.500000 0.500000 0.800000 0.800000")

        # Save to the FINAL dataset folder
        final_name = f"synth_{class_name}_{os.path.splitext(filename)[0]}"
        with open(os.path.join(FINAL_DATASET_DIR, 'train', 'labels', f"{final_name}.txt"), 'w') as f:
            f.write("\n".join(labels))
        cv2.imwrite(os.path.join(FINAL_DATASET_DIR, 'train', 'images', f"{final_name}.jpg"), image)

print("Stage 1 update complete.")
# Out:
# STAGE 1: Annotating synthetic data with Fallback...
#   Processing sharp_object...
#
# 0: 640x640 2 knifes, 865.5ms
# Speed: 27.4ms preprocess, 865.5ms inference, 48.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 knifes, 2392.7ms
# Speed: 56.5ms preprocess, 2392.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 877.1ms
# Speed: 6.6ms preprocess, 877.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 vase, 940.6ms
# Speed: 8.1ms preprocess, 940.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 605.1ms
# Speed: 7.0ms preprocess, 605.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 575.7ms
# Speed: 5.8ms preprocess, 575.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 530.9ms
# Speed: 5.3ms preprocess, 530.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 knifes, 582.0ms
# Speed: 5.5ms preprocess, 582.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 scissors, 550.4ms
# Speed: 5.2ms preprocess, 550.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 scissors, 620.9ms
# Speed: 6.8ms preprocess, 620.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 scissors, 552.5ms
# Speed: 5.7ms preprocess, 552.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 scissors, 541.2ms
# Speed: 4.9ms preprocess, 541.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 scissors, 882.6ms
# Speed: 5.9ms preprocess, 882.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 849.9ms
# Speed: 8.0ms preprocess, 849.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 545.9ms
# Speed: 5.1ms preprocess, 545.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 542.2ms
# Speed: 5.0ms preprocess, 542.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 tie, 2 knifes, 545.3ms
# Speed: 4.9ms preprocess, 545.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 561.7ms
# Speed: 6.0ms preprocess, 561.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 555.1ms
# Speed: 5.1ms preprocess, 555.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 543.3ms
# Speed: 5.0ms preprocess, 543.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 knifes, 608.5ms
# Speed: 5.2ms preprocess, 608.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 knifes, 1 scissors, 592.2ms
# Speed: 6.5ms preprocess, 592.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 568.3ms
# Speed: 6.4ms preprocess, 568.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 892.3ms
# Speed: 9.3ms preprocess, 892.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 854.7ms
# Speed: 9.5ms preprocess, 854.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 knifes, 560.3ms
# Speed: 5.4ms preprocess, 560.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 632.7ms
# Speed: 5.9ms preprocess, 632.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 645.5ms
# Speed: 6.5ms preprocess, 645.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 569.4ms
# Speed: 5.8ms preprocess, 569.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 567.9ms
# Speed: 5.3ms preprocess, 567.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 knifes, 570.4ms
# Speed: 8.2ms preprocess, 570.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 knifes, 546.3ms
# Speed: 5.7ms preprocess, 546.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 knifes, 548.3ms
# Speed: 5.7ms preprocess, 548.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 scissors, 657.8ms
# Speed: 5.6ms preprocess, 657.8ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 867.0ms
# Speed: 7.1ms preprocess, 867.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 knifes, 880.8ms
# Speed: 6.8ms preprocess, 880.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 544.3ms
# Speed: 5.5ms preprocess, 544.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 1 scissors, 555.4ms
# Speed: 5.3ms preprocess, 555.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 568.8ms
# Speed: 5.7ms preprocess, 568.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 knifes, 1 cell phone, 1 scissors, 568.3ms
# Speed: 5.3ms preprocess, 568.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 591.1ms
# Speed: 6.0ms preprocess, 591.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 knifes, 565.3ms
# Speed: 5.5ms preprocess, 565.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 knifes, 561.2ms
# Speed: 5.5ms preprocess, 561.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 scissors, 556.1ms
# Speed: 5.4ms preprocess, 556.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 knife, 2 scissorss, 546.8ms
# Speed: 5.3ms preprocess, 546.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 airplane, 864.9ms
# Speed: 7.0ms preprocess, 864.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 scissors, 853.6ms
# Speed: 7.8ms preprocess, 853.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-899950334.py in <cell line: 0>()
#      19         # AI Detection attempt
#      20         if class_name == 'sharp_object':
# ---> 21             res = base_model(image)[0]
#      22             for box in res.boxes:
#      23                 if int(box.cls) in [43, 76]:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     175             ...     print(f"Detected {len(r)} objects in image")
#     176         """
# --> 177         return self.predict(source, stream, **kwargs)
#     178
#     179     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     223             return self.stream_inference(source, model, *args, **kwargs)
#     224         else:
# --> 225             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Results into one
#     226
#     227     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      36             # Issuing `None` to a generator fires it up
#      37             with ctx_factory():
# ---> 38                 response = gen.send(None)
#      39
#      40             while True:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     328                 # Inference
#     329                 with profilers[1]:
# --> 330                     preds = self.inference(im, *args, **kwargs)
#     331                     if self.args.embed:
#     332                         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in inference(self, im, *args, **kwargs)
#     180             else False
#     181         )
# --> 182         return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#     183
#     184     def pre_transform(self, im: list[np.ndarray]) -> list[np.ndarray]:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize, embed, **kwargs)
#     699         # PyTorch
#     700         if self.pt or self.nn_module:
# --> 701             y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     702
#     703         # TorchScript
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     140         if isinstance(x, dict):  # for cases of training and validating while training.
#     141             return self.loss(x, *args, **kwargs)
# --> 142         return self.predict(x, *args, **kwargs)
#     143
#     144     def predict(self, x, profile=False, visualize=False, augment=False, embed=None):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in predict(self, x, profile, visualize, augment, embed)
#     157         if augment:
#     158             return self._predict_augment(x)
# --> 159         return self._predict_once(x, profile, visualize, embed)
#     160
#     161     def _predict_once(self, x, profile=False, visualize=False, embed=None):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in _predict_once(self, x, profile, visualize, embed)
#     179             if profile:
#     180                 self._profile_one_layer(m, x, dt)
# --> 181             x = m(x)  # run
#     182             y.append(x if m.i in self.save else None)  # save output
#     183             if visualize:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/block.py in forward(self, x)
#     309         """Forward pass through C2f layer."""
#     310         y = list(self.cv1(x).chunk(2, 1))
# --> 311         y.extend(m(y[-1]) for m in self.m)
#     312         return self.cv2(torch.cat(y, 1))
#     313
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/block.py in <genexpr>(.0)
#     309         """Forward pass through C2f layer."""
#     310         y = list(self.cv1(x).chunk(2, 1))
# --> 311         y.extend(m(y[-1]) for m in self.m)
#     312         return self.cv2(torch.cat(y, 1))
#     313
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/block.py in forward(self, x)
#     479     def forward(self, x: torch.Tensor) -> torch.Tensor:
#     480         """Apply bottleneck with optional shortcut connection."""
# --> 481         return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#     482
#     483
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/conv.py in forward_fuse(self, x)
#      87             (torch.Tensor): Output tensor.
#      88         """
# ---> 89         return self.act(self.conv(x))
#      90
#      91
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     546
#     547     def forward(self, input: Tensor) -> Tensor:
# --> 548         return self._conv_forward(input, self.weight, self.bias)
#     549
#     550
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     541                 self.groups,
#     542             )
# --> 543         return F.conv2d(
#     544             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545         )
#
# KeyboardInterrupt:

# %%
# 5. STAGE 2: AUTO-ANNOTATE RAW PHOTOS
# ==========================================================
print("STAGE 2: Auto-annotating raw photos from RAW_IMAGES_DIR...")
raw_files = [f for f in os.listdir(RAW_IMAGES_DIR) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
image_counter = 0

for filename in raw_files:
    img_path = os.path.join(RAW_IMAGES_DIR, filename)
    image = cv2.imread(img_path)
    if image is None: continue
    h, w, _ = image.shape
    labels = []

    # YOLO Base (Knives/Scissors/Bottles)
    results = base_model(image)[0]
    for box in results.boxes:
        cid, xywh = int(box.cls), box.xywhn[0].tolist()
        coords = f"{xywh[0]:.6f} {xywh[1]:.6f} {xywh[2]:.6f} {xywh[3]:.6f}"
        if cid in [43, 76]: labels.append(f"{MY_CLASSES['sharp_object']} {coords}")
        elif cid == 39: labels.append(f"{MY_CLASSES['chemical_danger']} {coords}")

    # Roboflow Models (Batteries, Lego, Coins) -> Choking
    for m in [battery_model, lego_model, coin_model]:
        try:
            preds = m.predict(img_path, confidence=40).json()
            for p in preds['predictions']:
                labels.append(f"{MY_CLASSES['choking_hazard']} {get_yolo_coords(p, w, h)}")
        except Exception as e:
            print(f"      Warning: Failed to predict with {m} for {filename}: {e}")

    # Electrical Outlets -> Electrical Hazard
    try:
        e_preds = power_model.predict(img_path, confidence=40).json()
        for p in e_preds['predictions']:
            labels.append(f"{MY_CLASSES['electrical_hazard']} {get_yolo_coords(p, w, h)}")
    except Exception as e:
            print(f"      Warning: Failed to predict with power_model for {filename}: {e}")

    # Save results
    if labels: # Only save if detections were made
        with open(os.path.join(FINAL_DATASET_DIR, 'train', 'labels', filename.replace('.jpg', '.txt').replace('.png', '.txt')), 'w') as f:
            f.write("\n".join(labels))
        shutil.copy(img_path, os.path.join(FINAL_DATASET_DIR, 'train', 'images', filename))
        image_counter += 1
    else:
        print(f"      No detections made for raw image: {filename}. Skipping.")

print(f"STAGE 2 Complete. {image_counter} raw images annotated and added to dataset.")
# Out:
# STAGE 2: Auto-annotating raw photos from RAW_IMAGES_DIR...
#
# 0: 640x640 1 bed, 16.4ms
# Speed: 3.2ms preprocess, 16.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 bowl, 1 dining table, 1 mouse, 16.4ms
# Speed: 3.9ms preprocess, 16.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 scissorss, 16.4ms
# Speed: 2.9ms preprocess, 16.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 scissorss, 16.5ms
# Speed: 4.1ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 scissorss, 16.4ms
# Speed: 3.5ms preprocess, 16.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 scissorss, 16.4ms
# Speed: 3.7ms preprocess, 16.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 scissorss, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 scissorss, 16.5ms
# Speed: 3.6ms preprocess, 16.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 scissorss, 1 toothbrush, 16.5ms
# Speed: 3.6ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 scissorss, 16.5ms
# Speed: 5.1ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 sports ball, 2 scissorss, 1 toothbrush, 16.4ms
# Speed: 3.3ms preprocess, 16.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 scissorss, 16.5ms
# Speed: 3.7ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 clocks, 16.5ms
# Speed: 4.0ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 bowls, 2 donuts, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 cup, 16.5ms
# Speed: 6.2ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#       No detections made for raw image: battery_2.jpg. Skipping.
#
# 0: 640x640 1 frisbee, 1 apple, 1 clock, 1 teddy bear, 16.5ms
# Speed: 3.6ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 16.5ms
# Speed: 4.6ms preprocess, 16.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 bowl, 7 clocks, 16.5ms
# Speed: 4.0ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 16.4ms
# Speed: 3.7ms preprocess, 16.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 donuts, 16.5ms
# Speed: 4.7ms preprocess, 16.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 cup, 4 bowls, 2 clocks, 16.5ms
# Speed: 3.8ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 clocks, 16.5ms
# Speed: 4.0ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 bottles, 1 clock, 1 vase, 16.8ms
# Speed: 3.4ms preprocess, 16.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 bottles, 1 toilet, 7 vases, 16.5ms
# Speed: 5.0ms preprocess, 16.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 22 bottles, 1 refrigerator, 16.5ms
# Speed: 3.8ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 bottles, 1 refrigerator, 16.4ms
# Speed: 3.7ms preprocess, 16.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 bottles, 1 refrigerator, 16.5ms
# Speed: 3.7ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 bottles, 7 cups, 16.5ms
# Speed: 6.0ms preprocess, 16.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 bottles, 16.4ms
# Speed: 3.3ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 bottles, 5 cups, 2 bowls, 1 apple, 1 refrigerator, 16.4ms
# Speed: 3.8ms preprocess, 16.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 bottles, 2 cups, 1 refrigerator, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 bottles, 1 cup, 2 bowls, 1 refrigerator, 16.5ms
# Speed: 4.4ms preprocess, 16.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 16.5ms
# Speed: 3.3ms preprocess, 16.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#       No detections made for raw image: wires_0.jpg. Skipping.
#
# 0: 640x640 1 scissors, 16.4ms
# Speed: 4.1ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 cell phones, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 cell phone, 16.5ms
# Speed: 3.7ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 fork, 1 mouse, 16.4ms
# Speed: 3.0ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#       No detections made for raw image: wires_4.jpg. Skipping.
#
# 0: 640x640 1 toothbrush, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#       No detections made for raw image: wires_5.jpg. Skipping.
#
# 0: 640x640 (no detections), 16.5ms
# Speed: 3.1ms preprocess, 16.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#       No detections made for raw image: wires_6.jpg. Skipping.
#
# 0: 640x640 1 toothbrush, 16.5ms
# Speed: 5.3ms preprocess, 16.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# STAGE 2 Complete. 35 raw images annotated and added to dataset.

# %%
# 6. TRAINING
# ==========================================================
print("STAGE 3: Starting training...")
config = {
    'path': FINAL_DATASET_DIR,
    'train': 'train/images',
    'val': 'train/images',
    'names': {i: name for name, i in MY_CLASSES.items()}
}
with open(os.path.join(BASE_DIR, 'final_data.yaml'), 'w') as f:
    yaml.dump(config, f)

model = YOLO('yolov8n.pt')
model.train(data=os.path.join(BASE_DIR, 'final_data.yaml'), epochs=100, imgsz=640, name='safety_model_v3')

print("All stages complete. Model training finished.")
# Out:
# STAGE 3: Starting training...
# Ultralytics 8.4.5 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/Shared drives/ChildSafetyProject/final_data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=safety_model_v33, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/safety_model_v33, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 1.4±1.6 ms, read: 0.3±0.1 MB/s, size: 116.8 KB)
# train: Scanning /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/labels... 439 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 439/439 3.4it/s 2:09
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/battery_1.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/battery_8.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0001.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0006.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0012.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0014.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0020.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_single_coin_on_white_background_isolated_0001.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_single_coin_on_white_background_isolated_0007.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0001.jpg: 7 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0003.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0004.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0006.jpg: 4 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0009.jpg: 10 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0010.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0011.jpg: 6 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0012.jpg: 2 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0015.jpg: 8 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0018.jpg: 2 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0022.jpg: 2 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0023.jpg: 12 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_small_colorful_ball_on_white_background_isolated_0024.jpg: 1 duplicate labels removed
# train: New cache created: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.6±0.4 ms, read: 35.6±13.5 MB/s, size: 110.9 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/labels.cache... 439 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 439/439 13.1Mit/s 0.0s
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/battery_1.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/battery_8.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0001.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0006.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0012.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0014.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_Lego_plastic_piece_on_white_background_isolated_0020.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A_single_coin_on_white_background_isolated_0001.jpg: 1 duplicate labels removed
# train: /content/drive/.shortcut-targets-by-id/1l5Z_nOrOzY2A1oY6fY6Cm-P2j8FH6YBf/ChildSafetyProject/final_combined_dataset/train/images/synth_choking_hazard_A
# Ultralytics 8.4.5 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 73 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 1.7it/s 8.0s
#                    all        439       4157      0.932      0.881       0.93       0.84
#           sharp_object        111        238      0.986       0.86      0.941      0.826
#         choking_hazard        134       3531       0.87      0.724      0.819      0.702
#      electrical_hazard        100        102      0.985      0.971      0.982      0.903
#        chemical_danger        114        286      0.889      0.969      0.978      0.929
# Speed: 0.2ms preprocess, 2.5ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to /content/runs/detect/safety_model_v33
# All stages complete. Model training finished.

# %%
# 1. DISPLAY TRAINING METRICS (Confusion Matrix & Graphs)
# ==========================================================
import os
from IPython.display import Image, display

# Path to the latest training run
# Check your Colab file browser to ensure the folder name is 'safety_model_v3' or 'child_safety_v3_fixed'
TRAIN_RUN_PATH = '/content/runs/detect/safety_model_v33'

print("--- Confusion Matrix ---")
display(Image(filename=os.path.join(TRAIN_RUN_PATH, 'confusion_matrix.png'), width=800))

print("\n--- Training Results (Loss and Metrics) ---")
display(Image(filename=os.path.join(TRAIN_RUN_PATH, 'results.png'), width=800))

print("\n--- F1 Curve ---")
display(Image(filename=os.path.join(TRAIN_RUN_PATH, 'F1_curve.png'), width=800))
# Out:
# --- Confusion Matrix ---
# --- Training Results (Loss and Metrics) ---
# --- F1 Curve ---
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4135988704.py in <cell line: 0>()
#      15
#      16 print("\n--- F1 Curve ---")
# ---> 17 display(Image(filename=os.path.join(TRAIN_RUN_PATH, 'F1_curve.png'), width=800))
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs/detect/safety_model_v33/F1_curve.png'

# %%
import os
import glob
from IPython.display import Image, display

# 1. Automatically find the latest training directory
runs_path = '/content/runs/detect'
all_runs = glob.glob(os.path.join(runs_path, '*/'))
if all_runs:
    # Sort by creation time to get the newest folder
    latest_run = max(all_runs, key=os.path.getmtime)
    print(f"Using results from: {latest_run}")

    # List of files we want to display
    metrics_to_show = [
        'confusion_matrix.png',
        'results.png',
        'F1_curve.png',
        'PR_curve.png'
    ]

    for metric in metrics_to_show:
        img_path = os.path.join(latest_run, metric)
        if os.path.exists(img_path):
            print(f"\n--- {metric} ---")
            display(Image(filename=img_path, width=800))
        else:
            print(f"File {metric} not found in this run.")
else:
    print("No training runs found in /content/runs/detect. Check if training finished successfully.")
# Out:
# Using results from: /content/runs/detect/safety_model_v33/
#
# --- confusion_matrix.png ---
# --- results.png ---
# File F1_curve.png not found in this run.
# File PR_curve.png not found in this run.

# %%
# 2. RUN INFERENCE ON TEST IMAGES
# ==========================================================
from ultralytics import YOLO
import glob
import matplotlib.pyplot as plt

# Load the best weights from your Drive or Colab runs
MODEL_PATH = os.path.join(TRAIN_RUN_PATH, 'weights/best.pt')
model = YOLO(MODEL_PATH)

# Path to your raw images for testing
TEST_IMAGES = glob.glob(os.path.join(RAW_IMAGES_DIR, "*.jpg"))[:10] # Take first 5 images

print("\n--- Model Predictions on Real Photos ---")

for img_path in TEST_IMAGES:
    # Run prediction
    results = model.predict(source=img_path, conf=0.25, save=False)

    # Plot results
    res_plotted = results[0].plot()

    # Convert BGR to RGB for matplotlib
    res_rgb = cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(10, 10))
    plt.imshow(res_rgb)
    plt.axis('off')
    plt.title(f"Detection: {os.path.basename(img_path)}")
    plt.show()
